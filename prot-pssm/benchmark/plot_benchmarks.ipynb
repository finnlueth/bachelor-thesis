# %%
# %load_ext autoreload
# %autoreload 2

from plot_benchmarks import plot_scope_benchmarks
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-mmd1ujm9 because the default path (/home/lfi/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
paths = {
    "Foldseek (PDB vs PDB - SCOPe)": "../tmp/data/pssm_generated_rocx/baselines/0_foldseek_pdb_vs_pdb_scope.rocx",
    "MMseqs2 (AA vs AA - SCOPe)": "../tmp/data/pssm_generated_rocx/baselines/0_mmseqs_aa_vs_aa_scope.rocx",
    "Foldseek (3Di vs 3Di - ProstT5)": "../tmp/data/pssm_generated_rocx/baselines/0_foldseek_3Di_vs_3Di_prost.rocx",
    # "Foldseek (ProstT5 Profile vs ProstT5 3Di - MDPSSM: Temperatures: All, Replica: 0)": "../tmp/data/pssm_generated_rocx/prot-md-pssm_ProstT5_2025-04-16-19-35-52_temp-all_repl-0.rocx",
    "Foldseek (ProstT5 MDPSSM vs ProstT5 3Di - : Temperatures: 320, Replica: All)": "../tmp/data/pssm_generated_rocx/prot-md-pssm_ProstT5_2025-04-16-19-42-11_temp-320_repl-all.rocx",
    # "Foldseek (ProstT5 Profile vs ProstT5 3Di - MDPSSM: Temperatures: 450, Replica: All)": "../tmp/data/pssm_generated_rocx/prot-md-pssm_ProstT5_2025-04-16-19-42-44_temp-450_repl-all.rocx",
    # "Foldseek (ProtT5 Profile vs ProstT5 3Di - MDPSSM: Temperatures: All, Replica: 0)": "../tmp/data/pssm_generated_rocx/prot-md-pssm_prot_t5_xl_uniref50_2025-04-16-19-37-14_temp-all_repl-0.rocx",
    # "Foldseek (ProtT5 Profile vs ProstT5 3Di - MDPSSM: Temperatures: All, Replica: 0) Improved?": "../tmp/data/pssm_generated_rocx/prot-md-pssm_prot_t5_xl_uniref50_2025-04-21-16-52-58_temp-all_repl-0.rocx",
    # "Foldseek (ProtT5 Profile vs ProstT5 3Di - MDPSSM: Temperatures: All, Replica: 0) OLD": "../tmp/data/pssm_generated_rocx/baselines/5_prot_old_foldseek_pssm_3Di.rocx",
    "Foldseek (ProstT5 MDPSSM vs ProstT5 3Di": "../tmp/data/pssm_generated_rocx/prot-md-pssm_ProstT5_2025-04-22-10-24-52_temp-320_repl-0.rocx",
}

plot_scope_benchmarks(paths)
# Out:
# /home/lfi/mnt/dev/prot-pssm/benchmark/plot_benchmarks.py:43: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()
